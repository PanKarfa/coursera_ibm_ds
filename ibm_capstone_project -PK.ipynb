# %% [markdown]
# # IBM Capstone notebook in Data Science
#
# This is the notebook for the final module of the Data science course on Coursera, offered by IBM.

# %%
import pandas as pd
import numpy as np
print("Hello there! Let's finish this capstone, once and for all!")# IBM Capstone notebook in Data Science

This is the notebook for the final module of the Data science course on Coursera, offered by IBM.
